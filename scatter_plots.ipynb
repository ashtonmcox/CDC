# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# %%
df = pd.read_pickle("my_dataframe.pkl")

# Create scatter plot
sns.scatterplot(data=df, x='fare', y='fare_low', palette='deep')
sns.regplot(data=df, x='fare', y='fare_low', scatter_kws={'s': 20}, line_kws={'color': 'red'})


# Add titles and labels
plt.title('Fare vs. Fare Low')
plt.xlabel('Fare')
plt.ylabel('Fare Low')

# Show plot
plt.show()
# Out:
# /var/folders/x3/3znnlncn36dgv5dbvysk08400000gn/T/ipykernel_2694/1223214558.py:6: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.scatterplot(data=df, x='fare', y='fare_low', palette='deep')

# %%
df = pd.read_pickle("my_dataframe.pkl")

# Create scatter plot
sns.scatterplot(data=df, x='large_ms', y='fare', palette='deep')

# Add titles and labels
plt.title('Large Market Share vs. Fare')
plt.xlabel('Large Market Share')
plt.ylabel('Fare')

# Show plot
plt.show()
# Out:
# /var/folders/x3/3znnlncn36dgv5dbvysk08400000gn/T/ipykernel_2694/2268076695.py:6: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.scatterplot(data=df, x='large_ms', y='fare', palette='deep')

# %%
df = pd.read_pickle("my_dataframe.pkl")

# Create scatter plot
sns.scatterplot(data=df, x='Year', y='fare', palette='deep')

# Add titles and labels
plt.title('Year vs. Fare')
plt.xlabel('Year')
plt.ylabel('Fare')

# Show plot
plt.show()
# Out:
# /var/folders/x3/3znnlncn36dgv5dbvysk08400000gn/T/ipykernel_2694/4046243100.py:6: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.scatterplot(data=df, x='Year', y='fare', palette='deep')

# %%
df = pd.read_pickle("my_dataframe.pkl")

# Create scatter plot
sns.scatterplot(data=df, x='city1', y='fare', palette='deep')

# Add titles and labels
plt.title('City vs. Fare')
plt.xlabel('City')
plt.ylabel('Fare')

# Show plot
plt.show()
# Out:
# /var/folders/x3/3znnlncn36dgv5dbvysk08400000gn/T/ipykernel_2694/2700775654.py:4: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.scatterplot(data=df, x='city1', y='fare', palette='deep')
